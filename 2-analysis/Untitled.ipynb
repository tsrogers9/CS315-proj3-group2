# %%
import pandas as pd

# Replace 'file_path.csv' with your file's path
male_all_description = pd.read_csv('M_all_vid_descriptions_2024_04_28.csv')

# %%
male_all_description
# Out:
#                 video_id                                 description_string  \
# 0    7359310165461568798  do you know what drives me nuts about what’s g...
# 1    7355557230193773866                         totalof my heart ❤️👨‍👩‍👧‍👦
# 2    7345476833854508319  icymi: i dive into the momentwalked into thean...
# 3    7345202286848642347                            re: joe biden’s stutter
# 4    7344046721384582431  anmessage from my mom.mom was one of the first...
# ..                   ...                                                ...
# 951  7308890266239552814  🚨teaser alert🚨: medicare advantage is one of t...
# 952  7306649030644206890  step 1: strengthen medicare. step 2: medicare ...
# 953  7302143436851809578  the topic of medicare advantage is deeply pers...
# 954  7301454548730711338  question: what would you call the ex-president...
# 955  7298830746351832366  i'm introducing legislation to create a nation...
#
#                                       description_list
# 0    ['do', 'you', 'know', 'what', 'drives', 'me', ...
# 1                           ['totalof', 'my', 'heart']
# 2    ['icymi', 'i', 'dive', 'into', 'the', 'momentw...
# 3                   ['re', 'joe', 'bidens', 'stutter']
# 4    ['anmessage', 'from', 'my', 'mommom', 'was', '...
# ..                                                 ...
# 951  ['teaser', 'alert', 'medicare', 'advantage', '...
# 952  ['step', 'strengthen', 'medicare', 'step', 'me...
# 953  ['the', 'topic', 'of', 'medicare', 'advantage'...
# 954  ['question', 'what', 'would', 'you', 'call', '...
# 955  ['im', 'introducing', 'legislation', 'to', 'cr...
#
# [956 rows x 3 columns]

# %%
male_categories = pd.read_csv('male_categories_all.csv')

# %%
male_categories
# Out:
#                 video_id                                        Description
# 0    7283952208561933599                            defense, law, and crime
# 1    7278392468788366634                            defense, law, and crime
# 2    7257715712897125675                            defense, law, and crime
# 3    7357176379433094442                       health, education, and labor
# 4    7356391987936873771                       health, education, and labor
# ..                   ...                                                ...
# 969  7162640962437582122                                              other
# 970  7157473128728349994   civil rights, immigration and international a...
# 971  7157405511741132078                                       civil rights
# 972  7155928934750653742                                            culture
# 973  7153766037387873582                                          education
#
# [974 rows x 2 columns]

# %%
male_categories.rename(columns={'Description': 'Category'}, inplace=True)

# %%
male_categories
# Out:
#                 video_id                                           Category
# 0    7283952208561933599                            defense, law, and crime
# 1    7278392468788366634                            defense, law, and crime
# 2    7257715712897125675                            defense, law, and crime
# 3    7357176379433094442                       health, education, and labor
# 4    7356391987936873771                       health, education, and labor
# ..                   ...                                                ...
# 969  7162640962437582122                                              other
# 970  7157473128728349994   civil rights, immigration and international a...
# 971  7157405511741132078                                       civil rights
# 972  7155928934750653742                                            culture
# 973  7153766037387873582                                          education
#
# [974 rows x 2 columns]

# %%
mask = ~male_categories['video_id'].isin(male_all_description['video_id'])

# Filter male_categories with the mask
non_matching_categories = male_categories[mask]

# %%
non_matching_categories
# Out:
#                 video_id                       Category
# 0    7283952208561933599        defense, law, and crime
# 1    7278392468788366634        defense, law, and crime
# 2    7257715712897125675        defense, law, and crime
# 3    7357176379433094442   health, education, and labor
# 4    7356391987936873771   health, education, and labor
# ..                   ...                            ...
# 792  7227133416356105518                          other
# 793  7226838827837558058                   civil rights
# 794  7226793691812220203                          other
# 795  7226374163689327918                          other
# 796  7226090544584232235                          other
#
# [468 rows x 2 columns]

# %%
merged_male = pd.merge(male_categories, male_all_description, on='video_id', how='outer')

# %%
# Out:
#                  video_id                                Category  \
# 0     6769961060226075909                                   other
# 1     6769978510497844485                                 culture
# 2     6829721401499421957            health, education, and labor
# 3     6907019172203613446                                     NaN
# 4     6924425222460411141                                   other
# ...                   ...                                     ...
# 1478  7359310165461568798                                     NaN
# 1479  7359600432097824043              housing and social welfare
# 1480  7359609189032824095                                     NaN
# 1481  7359628313263901995                                     NaN
# 1482  7359659366636719403   economy, commerce, and transportation
#
#                                      description_string  \
# 0                 hello tiktok, i’m rep. mark takano 👋🏼
# 1              baking a cake with the sweet feminist ☂️
# 2     $13 billion inrelief funding in theshould be g...
# 3                                          44 + 46 = ❤️
# 4     i am running to bein the house of representati...
# ...                                                 ...
# 1478  do you know what drives me nuts about what’s g...
# 1479  we cannot allow the supreme court or local gov...
# 1480  the affordable connectivity program serves ove...
# 1481  here’s a question you don’t hear the corporate...
# 1482  t*cketmaster & j*e alwin getting cooked today ...
#
#                                        description_list
# 0     ['hello', 'tiktok', 'im', 'rep', 'mark', 'taka...
# 1     ['baking', 'a', 'cake', 'with', 'the', 'sweet'...
# 2     ['billion', 'inrelief', 'funding', 'in', 'thes...
# 3                                                    []
# 4     ['i', 'am', 'running', 'to', 'bein', 'the', 'h...
# ...                                                 ...
# 1478  ['do', 'you', 'know', 'what', 'drives', 'me', ...
# 1479  ['we', 'cannot', 'allow', 'the', 'supreme', 'c...
# 1480  ['the', 'affordable', 'connectivity', 'program...
# 1481  ['heres', 'a', 'question', 'you', 'dont', 'hea...
# 1482  ['tcketmaster', 'je', 'alwin', 'getting', 'coo...
#
# [1483 rows x 4 columns]

# %%
males_with_na = merged_male[merged_male['Category'].isna()]

# %%
males_with_na
# Out:
#                  video_id Category  \
# 3     6907019172203613446      NaN
# 19    6943558317230836997      NaN
# 22    6950845821256600838      NaN
# 23    6951239972552740101      NaN
# 24    6952982461215214854      NaN
# ...                   ...      ...
# 1471  7358909058545601838      NaN
# 1476  7359243722246081823      NaN
# 1478  7359310165461568798      NaN
# 1480  7359609189032824095      NaN
# 1481  7359628313263901995      NaN
#
#                                      description_string  \
# 3                                          44 + 46 = ❤️
# 19                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                          it’s me,! 👀
# ...                                                 ...
# 1471    not another nickle for netanyahu’s war machine.
# 1476  this week, the house small business subcommitt...
# 1478  do you know what drives me nuts about what’s g...
# 1480  the affordable connectivity program serves ove...
# 1481  here’s a question you don’t hear the corporate...
#
#                                        description_list
# 3                                                    []
# 19                                                   []
# 22                                                   []
# 23                                                   []
# 24                                        ['its', 'me']
# ...                                                 ...
# 1471  ['not', 'another', 'nickle', 'for', 'netanyahu...
# 1476  ['this', 'week', 'the', 'house', 'small', 'bus...
# 1478  ['do', 'you', 'know', 'what', 'drives', 'me', ...
# 1480  ['the', 'affordable', 'connectivity', 'program...
# 1481  ['heres', 'a', 'question', 'you', 'dont', 'hea...
#
# [509 rows x 4 columns]

# %%
female_categories = pd.read_csv('female_categories.csv')

# %%
female_all_description = pd.read_csv('F_all_vid_descriptions_2024_04_28.csv')

# %%
mask = ~female_categories['video_id'].isin(female_all_description['video_id'])

# %%
non_matching_categories = female_categories[mask]

# %%
non_matching_categories
# Out:
# Empty DataFrame
# Columns: [video_id, Description]
# Index: []

# %%
female_all_description
# Out:
#                 video_id                                 description_string  \
# 0    7283952208561933599  we all know who the grand puppet master is in ...
# 1    7278392468788366634  if the majority wants to talk about dark money...
# 2    7257715712897125675  the party of ‘law and order” 🤔lol, they litera...
# 3    7357176379433094442  no one should have the right to tell women wha...
# 4    7356391987936873771  i ran for congress because i was sick of polit...
# ..                   ...                                                ...
# 441  7163807350543928619                                     we vote within
# 442  7163802367308074282  as long as you’re in line by 8pm the polls mus...
# 443  7163458954188623150            be like yama and make your voice heard!
# 444  7162576451697511726  don’t mail your ballot, drop it off at a dropb...
# 445  7162575529726446891  be sure to fill out your entire ballot! if you...
#
#                                       description_list
# 0    ['we', 'all', 'know', 'who', 'the', 'grand', '...
# 1    ['if', 'the', 'majority', 'wants', 'to', 'talk...
# 2    ['the', 'party', 'of', 'law', 'and', 'order', ...
# 3    ['no', 'one', 'should', 'have', 'the', 'right'...
# 4    ['i', 'ran', 'for', 'congress', 'because', 'i'...
# ..                                                 ...
# 441                           ['we', 'vote', 'within']
# 442  ['as', 'long', 'as', 'youre', 'in', 'line', 'b...
# 443  ['be', 'like', 'yama', 'and', 'make', 'your', ...
# 444  ['dont', 'mail', 'your', 'ballot', 'drop', 'it...
# 445  ['be', 'sure', 'to', 'fill', 'out', 'your', 'e...
#
# [446 rows x 3 columns]

# %%
female_categories
# Out:
#                 video_id                                        Description
# 0    7325202367341727019              immigration and international affairs
# 1    7322564437032897834                            defense, law, and crime
# 2    7322506528307645739                            defense, law, and crime
# 3    7321188330094234923                            defense, law, and crime
# 4    7312955628111007022                            defense, law, and crime
# ..                   ...                                                ...
# 433  7330670871394225451              economy, commerce, and transportation
# 434  7330036463138065707   immigration and international affairs, defens...
# 435  7325587998370958638                             energy and environment
# 436  7325490784348753195              immigration and international affairs
# 437  7325213730659208490                       health, education, and labor
#
# [438 rows x 2 columns]

# %%
merged_female = pd.merge(female_categories, female_all_description, on='video_id', how='outer')

# %%
merged_female
# Out:
#                 video_id                                        Description  \
# 0    6995183391595449605                                              other
# 1    6995619470706314502              economy, commerce, and transportation
# 2    6995933159049153797                                              other
# 3    6996394052715351302                                              other
# 4    6996721852626242821                                              other
# ..                   ...                                                ...
# 441  7356257374031596843                       health, education, and labor
# 442  7356276971082452270              economy, commerce, and transportation
# 443  7356391987936873771   health, education, and labor, housing and soc...
# 444  7357028369654877486                       health, education, and labor
# 445  7357176379433094442         health, education, and labor, civil rights
#
#                                     description_string  \
# 0    hello, tiktok! got any questions for me? my q&...
# 1    we're going to make life a whole lot easier fo...
# 2    maple is more interested in chasing squirrels ...
# 3                                        lake placid 🌅
# 4       maple had a little too much fun on the lake...
# ..                                                 ...
# 441  we’re going to cancel student debt! 30 million...
# 442  it’s official! my bipartisan veterans and outd...
# 443  i ran for congress because i was sick of polit...
# 444  fact: fda rigorously reviewed mifepristone res...
# 445  no one should have the right to tell women wha...
#
#                                       description_list
# 0    ['hello', 'tiktok', 'got', 'any', 'questions',...
# 1    ['were', 'going', 'to', 'make', 'life', 'a', '...
# 2    ['maple', 'is', 'more', 'interested', 'in', 'c...
# 3                                   ['lake', 'placid']
# 4    ['maple', 'had', 'a', 'little', 'too', 'much',...
# ..                                                 ...
# 441  ['were', 'going', 'to', 'cancel', 'student', '...
# 442  ['its', 'official', 'my', 'bipartisan', 'veter...
# 443  ['i', 'ran', 'for', 'congress', 'because', 'i'...
# 444  ['fact', 'fda', 'rigorously', 'reviewed', 'mif...
# 445  ['no', 'one', 'should', 'have', 'the', 'right'...
#
# [446 rows x 4 columns]

# %%
merged_female.to_csv('female_manual_verification.csv', index=False)
